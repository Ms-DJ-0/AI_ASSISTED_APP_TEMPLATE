# %% [markdown]
# <a href="https://colab.research.google.com/github/CopingMoa/AI_ASSISTED_APP_TEMPLATE/blob/main/EBM_simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
